# %%
#Importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O 
import os
import matplotlib.pyplot as plt#visualization
from PIL import  Image
# %matplotlib inline
import pandas as pd
import seaborn as sns#visualization
import itertools
import warnings
warnings.filterwarnings("ignore")
import io
import plotly.offline as py#visualization
py.init_notebook_mode(connected=True)#visualization
import plotly.graph_objs as go#visualization
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data= pd.read_csv (r"C:\Users\sneha\OneDrive\Documents\admission.csv")

# %% [markdown]
# ### Q.1

# %%
data.sample(10)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 111         112        321          109                  4  4.0   4.0  8.68
# 418         419        309          111                  2  2.5   4.0  8.03
# 85           86        319          103                  4  4.5   3.5  8.66
# 469         470        326          114                  4  4.0   3.5  9.16
# 256         257        309           99                  3  4.0   4.0  8.56
# 367         368        311           98                  1  1.0   2.5  7.46
# 314         315        305          105                  2  3.0   4.0  8.13
# 195         196        307          107                  2  3.0   3.5  8.52
# 184         185        316          106                  2  2.5   4.0  8.32
# 394         395        329          111                  4  4.5   4.0  9.23
#
#      Research  Chance of Admit
# 111         1              0.69
# 418         0              0.60
# 85          0              0.76
# ...

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
data.shape
# Out:
# (500, 9)

# %%
data.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.103839    -0.141696          -0.067641
# GRE Score           -0.103839   1.000000     0.827200           0.635376
# TOEFL Score         -0.141696   0.827200     1.000000           0.649799
# University Rating   -0.067641   0.635376     0.649799           1.000000
# SOP                 -0.137352   0.613498     0.644410           0.728024
# LOR                 -0.003694   0.524679     0.541563           0.608651
# CGPA                -0.074289   0.825878     0.810574           0.705254
# Research            -0.005332   0.563398     0.467012           0.427047
# Chance of Admit      0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332          0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398          0.810351
# ...

# %%
sns.pairplot(data=data)

# %%
data.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
data.columns = data.columns.str.replace(' ','_')
data.columns
# Out:
# Index(['Serial_No.', 'GRE_Score', 'TOEFL_Score', 'University_Rating', 'SOP',
#        'LOR_', 'CGPA', 'Research', 'Chance_of_Admit_'],
#       dtype='object')

# %% [markdown]
# ### Q.2

# %%
data.describe()
# Out:
#        Serial_No.   GRE_Score  TOEFL_Score  University_Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR_        CGPA    Research  Chance_of_Admit_
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %% [markdown]
# ### for GRE score min value is 290
# # max value is 340

# %% [markdown]
# ### Q.3

# %%
data.University_Rating.value_counts(round)*100
# Out:
# 3    32.4
# 2    25.2
# 4    21.0
# 5    14.6
# 1     6.8
# Name: University_Rating, dtype: float64

# %% [markdown]
# ### Q.4

# %%
def admission(data):
    if data['Chance_of_Admit_'] <0.80:
        return '0'
    elif data['Chance_of_Admit_'] >=0.80:
         return '1'
data['Chance_of_Admit_'] =data.apply(lambda data : admission(data), axis =1)

# %%
data.head()
# Out:
#    Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research Chance_of_Admit_
# 0         1                1
# 1         1                0
# 2         1                0
# 3         1                1
# 4         0                0

# %%
import seaborn as sns
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
Q1 = data['LOR_'].quantile(0.25)
Q3 = data['LOR_'].quantile(0.75)

IQR = Q3- Q1
lower_limit= Q1 - 1.5*IQR
lower_limit
# Out:
# 1.5

# %%
data['LOR_']=np.where(data['LOR_']< lower_limit,lower_limit,data['LOR_'])

# %%
import seaborn as sns
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### data partition

# %%
from sklearn.model_selection import train_test_split
#from random import seed

#seed(20)
x = data.drop(['Chance_of_Admit_'],axis=1)
y = data[['Chance_of_Admit_']]

# Train test split

X_train, X_test, y_train, y_test =train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn import tree

dt = tree.DecisionTreeClassifier()  # by default it use Gini index for split
#Train the model using the training sets
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
train=pd.concat([y_train,X_train],axis=1)
train.head()
# Out:
#     Chance_of_Admit_  Serial_No.  GRE_Score  TOEFL_Score  University_Rating  \
# 153                0         154        324          105                  3
# 84                 1          85        340          115                  5
# 310                0         311        320          104                  3
# 494                0         495        301           99                  3
# 126                1         127        323          113                  3
#
#      SOP  LOR_  CGPA  Research
# 153  3.0   4.0  8.75         0
# 84   4.5   4.5  9.45         1
# 310  3.0   3.5  8.74         1
# 494  2.5   2.0  8.45         1
# 126  4.0   3.0  9.32         1

# %%
independent_variable = list(train.columns[1:])
independent_variable
# Out:
# ['Serial_No.',
#  'GRE_Score',
#  'TOEFL_Score',
#  'University_Rating',
#  'SOP',
#  'LOR_',
#  'CGPA',
#  'Research']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
params = { 'min_samples_split': [150,175,250], ## Parent 
           'min_samples_leaf': [50,65,70], ## Child or Leave 
           'max_depth':[3,4,6]}  # Branches
grid_search_cv = GridSearchCV(DecisionTreeClassifier(random_state=42),
                              params, 
                              verbose=1, 
                              cv=10)
grid_search_cv.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'max_depth': [3, 4, 6],
#                          'min_samples_leaf': [50, 65, 70],
#                          'min_samples_split': [150, 175, 250]},
#              verbose=1)

# %%
grid_search_cv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=150,
#                        random_state=42)

# %%
from sklearn import tree

dt = tree.DecisionTreeClassifier(criterion='gini',  #splitter
                                 min_samples_leaf=50, ## child
                                 min_samples_split=150, #parent 
                                 max_depth=3)  #branches
#Train the model using the training sets
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=150)

# %%
from sklearn import tree
import matplotlib.pyplot as plt

Chance_of_Admit_=['0', '1']  # array
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (5,4), dpi=300)
tree.plot_tree(dt,  # Model 
               feature_names = independent_variable,  # column name
               class_names=Chance_of_Admit_, # Yes , No
               filled = True, # colour
              node_ids=True, # node number
              fontsize=2);

# %%
train['Predicted']=dt.predict(X_train)  # MODEL = dt
train.head()
# Out:
#     Chance_of_Admit_  Serial_No.  GRE_Score  TOEFL_Score  University_Rating  \
# 153                0         154        324          105                  3
# 84                 1          85        340          115                  5
# 310                0         311        320          104                  3
# 494                0         495        301           99                  3
# 126                1         127        323          113                  3
#
#      SOP  LOR_  CGPA  Research Predicted
# 153  3.0   4.0  8.75         0         0
# 84   4.5   4.5  9.45         1         1
# 310  3.0   3.5  8.74         1         0
# 494  2.5   2.0  8.45         1         0
# 126  4.0   3.0  9.32         1         1

# %%
from sklearn.metrics import classification_report
print(classification_report(train['Chance_of_Admit_'], train['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       242
#            1       0.82      0.90      0.85       108
#
#     accuracy                           0.91       350
#    macro avg       0.88      0.90      0.89       350
# weighted avg       0.91      0.91      0.91       350

# %%
test=pd.concat([X_test,y_test],axis=1)
test.head()
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 69           70        328          115                  4  4.5   4.0  9.16
# 29           30        310           99                  2  1.5   2.0  7.30
# 471         472        311          103                  3  2.0   4.0  8.09
# 344         345        295           96                  2  1.5   2.0  7.34
# 54           55        322          110                  3  3.0   3.5  8.00
#
#      Research Chance_of_Admit_
# 69          1                0
# 29          0                0
# 471         0                0
# 344         0                0
# 54          0                0

# %%
test['Predicted']=dt.predict(X_test)
test.head()
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 69           70        328          115                  4  4.5   4.0  9.16
# 29           30        310           99                  2  1.5   2.0  7.30
# 471         472        311          103                  3  2.0   4.0  8.09
# 344         345        295           96                  2  1.5   2.0  7.34
# 54           55        322          110                  3  3.0   3.5  8.00
#
#      Research Chance_of_Admit_ Predicted
# 69          1                0         1
# 29          0                0         0
# 471         0                0         0
# 344         0                0         0
# 54          0                0         0

# %%
from sklearn.metrics import classification_report
print(classification_report(test['Chance_of_Admit_'], test['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       103
#            1       0.92      0.96      0.94        47
#
#     accuracy                           0.96       150
#    macro avg       0.95      0.96      0.95       150
# weighted avg       0.96      0.96      0.96       150

# %% [markdown]
# ### conckusion
# #accuracy for train dataset fount to be 92%
#
# #accuracy for test data found to be 93%
#
# #both indicates overfitting

# %% [markdown]
# ### Q.6

# %%
# ?RandomForestClassifier
# Out:
# Object `RandomForestClassifier` not found.

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# by default 100 tree will be form 
Model2= RandomForestClassifier(n_estimators=20, # make 20 tress
                               criterion="gini",
                               max_depth=3,  # each tree will have 4 branches
                               min_samples_split=150,# 150each tree will have parent node
                               min_samples_leaf=100,# each tree will have Child node
                               max_features="sqrt")# n_estimators means number tree we want  

Model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, max_features='sqrt', min_samples_leaf=100,
#                        min_samples_split=150, n_estimators=20)

# %%
list(X_train.columns)
# Out:
# ['Serial_No.',
#  'GRE_Score',
#  'TOEFL_Score',
#  'University_Rating',
#  'SOP',
#  'LOR_',
#  'CGPA',
#  'Research']

# %%
tree = Model2.estimators_[9]  # specify the tree number   
Chance_of_Admit_=['0','1'] 
feature_list = list(X_train.columns)  # all independent variable name

export_graphviz(tree, out_file = 'abc.dot', 
                feature_names = feature_list, 
                leaves_parallel=True,
                class_names=Chance_of_Admit_,
                rounded = True, 
                filled=True)
# Use dot file to create a graph
(graph,)= pydot.graph_from_dot_file('abc.dot')
# Write graph to a png file
graph.write_png('tree.png')
from IPython.display import Image
Image(filename = 'tree.png')

# %%
train['Predicted']=Model2.predict(X_train)
train.head()
# Out:
#     Chance_of_Admit_  Serial_No.  GRE_Score  TOEFL_Score  University_Rating  \
# 153                0         154        324          105                  3
# 84                 1          85        340          115                  5
# 310                0         311        320          104                  3
# 494                0         495        301           99                  3
# 126                1         127        323          113                  3
#
#      SOP  LOR_  CGPA  Research Predicted
# 153  3.0   4.0  8.75         0         0
# 84   4.5   4.5  9.45         1         1
# 310  3.0   3.5  8.74         1         0
# 494  2.5   2.0  8.45         1         0
# 126  4.0   3.0  9.32         1         1

# %%
from sklearn.metrics import classification_report
print(classification_report(train['Chance_of_Admit_'], train['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.90       242
#            1       0.75      0.87      0.81       108
#
#     accuracy                           0.87       350
#    macro avg       0.84      0.87      0.86       350
# weighted avg       0.88      0.87      0.87       350

# %%
test['Predicted']=Model2.predict(X_test)
test.head()
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 69           70        328          115                  4  4.5   4.0  9.16
# 29           30        310           99                  2  1.5   2.0  7.30
# 471         472        311          103                  3  2.0   4.0  8.09
# 344         345        295           96                  2  1.5   2.0  7.34
# 54           55        322          110                  3  3.0   3.5  8.00
#
#      Research Chance_of_Admit_ Predicted
# 69          1                0         1
# 29          0                0         0
# 471         0                0         0
# 344         0                0         0
# 54          0                0         0

# %%
from sklearn.metrics import classification_report

print(classification_report(test['Chance_of_Admit_'], test['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       103
#            1       0.82      0.87      0.85        47
#
#     accuracy                           0.90       150
#    macro avg       0.88      0.89      0.89       150
# weighted avg       0.90      0.90      0.90       150

# %%
#conclusion
#accuracy of train data set is 90%
#accuracy of test data set is 85%
#for  dataset student has low chance of getting admission because snsitivity is less than specificity

# %% [markdown]
# ### Q.7

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Define Model parameters to tune
# n_estimators=The number of boosting stages to perform.
model_parameters = {'n_estimators': [2,4,5], # number of tress
                    'max_depth':    [2, 3],      # maximum branches in tree
                    'learning_rate':[0.8, 0.6],
                    'min_samples_leaf':[100,200,270], ## child
                    'min_samples_split':[50,70,80]} #parent

# %%
model = GradientBoostingClassifier(random_state=10,loss="deviance",criterion="mse")
## random_state  -- The random number seed so that same random numbers are generated every time.

gscv_GBM = GridSearchCV(estimator=model, 
                    param_grid=model_parameters,  # comibnation = 4
                    cv=10,  # K-fold = 10 or 5  
                    verbose=1, ### message how many task done at backend
                    n_jobs=-1, ## parallel processing used entire processor
                    scoring='accuracy') ## accuracy evaluation

gscv_GBM.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# GridSearchCV(cv=10,
#              estimator=GradientBoostingClassifier(criterion='mse',
#                                                   random_state=10),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.8, 0.6], 'max_depth': [2, 3],
#                          'min_samples_leaf': [100, 200, 270],
#                          'min_samples_split': [50, 70, 80],
#                          'n_estimators': [2, 4, 5]},
#              scoring='accuracy', verbose=1)

# %%
print('The best parameter are -', gscv_GBM.best_params_)
# Out:
# The best parameter are - {'learning_rate': 0.8, 'max_depth': 2, 'min_samples_leaf': 100, 'min_samples_split': 50, 'n_estimators': 4}

# %%
# Re-fit the model with the best parameters
final_mod_GBM = GradientBoostingClassifier(**gscv_GBM.best_params_)
final_mod_GBM.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.8, max_depth=2, min_samples_leaf=100,
#                            min_samples_split=50, n_estimators=4)

# %%
train_pred = final_mod_GBM.predict(X_train)
test_pred = final_mod_GBM.predict(X_test)

# %%
print('Classification report for train data is : \n',
      classification_report(y_train, train_pred))
# Out:
# Classification report for train data is :
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       242
#            1       0.88      0.85      0.86       108
#
#     accuracy                           0.92       350
#    macro avg       0.91      0.90      0.90       350
# weighted avg       0.92      0.92      0.92       350

# %%
print('Classification report for train data is : \n',
      classification_report(y_test, test_pred))
# Out:
# Classification report for train data is :
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       103
#            1       0.92      0.96      0.94        47
#
#     accuracy                           0.96       150
#    macro avg       0.95      0.96      0.95       150
# weighted avg       0.96      0.96      0.96       150

# %% [markdown]
# ### Conclusion
# #accuracy of train data set is 93%
#
#
# #accuracy of test data set is 93%

# %%
from sklearn.tree import export_graphviz
sub_tree = final_mod_GBM.estimators_[0, 0] #0 to 99  # Model ( Final_mod_GBM) = Give Tree
Chance_of_Admit_=['0','1'] 
feature_list = list(X_train.columns)

# Visualization. Install graphviz in your system
from pydotplus import graph_from_dot_data
from IPython.display import Image
dot_data = export_graphviz(sub_tree,
    out_file=None,
    class_names=Chance_of_Admit_,
    feature_names = feature_list, 
    filled=True, 
    rounded=True,
    special_characters=True,
    impurity=False)

graph = graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# ### Q.9

# %% [markdown]
# ### conclusion for decision
# #accuracy of train data set is 92%
#
# #accuracy of test data set is 93%
#
# #for  dataset student has low chance of getting admission because snsitivity is less than specificity
#
# #model is overfitting
#
#
# ### conclusion for random forest
# #accuracy of train data set is 90%
#
# #accuracy of test data set is 85%
#
# #for  dataset student has low chance of getting admission because snsitivity is less than specificity
#
# #model is good fit
#
#
# ### Conclusion for gradient boosting
# #accuracy of train data set is 93%
#
#
# #accuracy of test data set is 93%
#
# #model is overfit

# %% [markdown]
# ### as model for random forest is best fit model
# # i choose randam forest for my dataset
